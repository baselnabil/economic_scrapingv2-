# %%
import pandas as pd

# %%
# organizng general info table
general_info_df = pd.read_csv('general_info.csv')
countries_columms= general_info_df.pop('Country')
general_info_df.insert(0, 'Country', countries_columms)
general_info_df

# %%
economic_indicatros_df = pd.read_csv('economic.csv')
countries_columms = economic_indicatros_df.pop('Country')
economic_indicatros_df.insert(0, 'Country', countries_columms)
economic_indicatros_df
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 227  Wallis and Futuna Islands
# 228             Western Sahara
# 229                      Yemen
# 230                     Zambia
# 231                   Zimbabwe
#
#     GDP: Gross domestic product (million current US$)  \
# 0                     ['14 699', '18 713', '17 877b']
# 1                     ['11 927', '11 387', '15 278b']
# 2                  ['161 207', '165 979', '171 158b']
# 3                                                 NaN
# 4                        ['3 447', '2 789', '3 154b']
# ..                                                ...
# 227                                               NaN
# 228                                               NaN
# 229                   ['30 907', '26 660', '24 935b']
# ...
